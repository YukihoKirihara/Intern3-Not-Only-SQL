# %%
# !pip install tushare
# !pip install pandas
# !pip install numpy
import tushare as ts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


## set this to your tushare token
ZHANKEYING_TUSHARE_TOKEN = "bd64f388adebe21dd43ab0d399352666593a145bdc6b92abcae33b3b"
ts.set_token(ZHANKEYING_TUSHARE_TOKEN)
pro = ts.pro_api()

data = pro.daily(ts_code='600019.SH', start_date='20110101', end_date='20230101')
## sort the data in trade_date
data.sort_values('trade_date', inplace = True,ascending= True)
## format the trade-date to "year-month-date"
data['trade_date'] = pd.to_datetime(data['trade_date'], format="%Y%m%d")
print(data.head(10))
## calculate the moving average of close
data['ma_100'] = data['close'].rolling(100).mean()
plt.figure()
plt.plot(data['trade_date'],data['ma_100'],label = 'ma_100')
plt.plot(data['trade_date'],data['close'],label = 'close')
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: tushare in d:\python3.9\lib\site-packages (1.2.89)
# Requirement already satisfied: pandas in d:\python3.9\lib\site-packages (from tushare) (2.0.1)
# Requirement already satisfied: requests in d:\python3.9\lib\site-packages (from tushare) (2.28.1)
# Requirement already satisfied: lxml in d:\python3.9\lib\site-packages (from tushare) (4.9.2)
# Requirement already satisfied: simplejson in d:\python3.9\lib\site-packages (from tushare) (3.19.1)
# Requirement already satisfied: bs4 in d:\python3.9\lib\site-packages (from tushare) (0.0.1)
# Requirement already satisfied: websocket-client==0.57.0 in d:\python3.9\lib\site-packages (from tushare) (0.57.0)
# Requirement already satisfied: six in d:\python3.9\lib\site-packages (from websocket-client==0.57.0->tushare) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in d:\python3.9\lib\site-packages (from bs4->tushare) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python3.9\lib\site-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python3.9\lib\site-packages (from pandas->tushare) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\python3.9\lib\site-packages (from pandas->tushare) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in d:\python3.9\lib\site-packages (from pandas->tushare) (1.24.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\python3.9\lib\site-packages (from requests->tushare) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\python3.9\lib\site-packages (from requests->tushare) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\python3.9\lib\site-packages (from requests->tushare) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python3.9\lib\site-packages (from requests->tushare) (2022.9.24)
# Requirement already satisfied: soupsieve>1.2 in d:\python3.9\lib\site-packages (from beautifulsoup4->bs4->tushare) (2.4.1)
# Requirement already satisfied: pandas in d:\python3.9\lib\site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python3.9\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\python3.9\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\python3.9\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in d:\python3.9\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in d:\python3.9\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in d:\python3.9\lib\site-packages (1.24.2)
#         ts_code trade_date  open  high   low  close  pre_close  change
# 2817  600019.SH 2011-01-04  6.44  6.56  6.31   6.55       6.39    0.16  \
# 2816  600019.SH 2011-01-05  6.49  6.50  6.42   6.45       6.55   -0.10
# 2815  600019.SH 2011-01-06  6.46  6.50  6.39   6.46       6.45    0.01
# 2814  600019.SH 2011-01-07  6.46  6.68  6.41   6.56       6.46    0.10
# 2813  600019.SH 2011-01-10  6.54  6.64  6.51   6.52       6.56   -0.04
# 2812  600019.SH 2011-01-11  6.52  6.72  6.51   6.70       6.52    0.18
# 2811  600019.SH 2011-01-12  6.72  6.90  6.67   6.83       6.70    0.13
# 2810  600019.SH 2011-01-13  6.87  6.90  6.73   6.77       6.83   -0.06
# 2809  600019.SH 2011-01-14  6.77  6.77  6.61   6.71       6.77   -0.06
# 2808  600019.SH 2011-01-17  6.64  6.74  6.48   6.53       6.71   -0.18
#
#       pct_chg        vol      amount
# 2817     2.50  572249.83  369381.672
# 2816    -1.53  334574.19  215978.272
# 2815     0.16  248061.88  159829.914
# 2814     1.55  562598.63  368965.887
# 2813    -0.61  422610.09  277610.464
# 2812     2.76  608401.78  403478.981
# 2811     1.94  815284.93  554413.060
# 2810    -0.88  511347.57  348201.644
# 2809    -0.89  415524.64  277649.450
# 2808    -2.68  524684.69  346912.702
